# %% [markdown]
# # CodesOnBytes Data Science Internship

# %% [markdown]
# ## AUTHOR - VYSHNAVI K.T

# %% [markdown]
# ### PHASE 1

# %% [markdown]
# ### Task 1 : Creating a csv dataset from api using python and pandas

# %% [markdown]
# #### Import the required libraries

# %%
import requests
import pandas as pd

# %% [markdown]
# #### Define the URL

# %%
url="https://data.binance.com/api/v3/ticker/24hr"

# %% [markdown]
# #### Send a get request to the api

# %%
response = requests.get(url)

# %% [markdown]
# #### Check if the request was successful

# %%
if response.status_code == 200:
    data = response.json()
    df = pd.DataFrame(data)
    csv_filename = "binance_ticker_data.csv"
    df.to_csv(csv_filename, index=False)
    print(f"CSV dataset saved as {csv_filename}")
else:
    print(f"Failed to retrieve data. Status code: {response.status_code}")
# Out:
# CSV dataset saved as binance_ticker_data.csv

# %% [markdown]
# #### Read the dataset using pandas

# %%
df=pd.read_csv("binance_ticker_data.csv")
df
# Out:
#          symbol  priceChange  priceChangePercent  weightedAvgPrice  \
# 0        ETHBTC     0.000320               0.528          0.060829
# 1        LTCBTC    -0.000027              -1.103          0.002431
# 2        BNBBTC     0.000001               0.012          0.008086
# 3        NEOBTC    -0.000002              -0.582          0.000274
# 4       QTUMETH     0.000003               0.223          0.001347
# ...         ...          ...                 ...               ...
# 2297    ARKUSDT    -0.003200              -0.605          0.552472
# 2298  CREAMUSDT    -0.940000              -5.054         18.546442
# 2299    GFTUSDT     0.003910              19.271          0.023411
# 2300     IQUSDT     0.000080               1.677          0.004914
# 2301    USDTVAI    -0.008000              -0.788          1.010881
#
#       prevClosePrice  lastPrice    lastQty   bidPrice      bidQty   askPrice  \
# 0           0.060580   0.060910     4.4416   0.060910      46.360   0.060920
# 1           0.002448   0.002421     4.2870   0.002420      19.630   0.002421
# 2           0.008078   0.008080    38.8160   0.008079      14.806   0.008080
# 3           0.000275   0.000273     4.4300   0.000273      31.600   0.000273
# 4           0.001348   0.001350     0.1000   0.001346      46.400   0.001352
# ...              ...        ...        ...        ...         ...        ...
# 2297        0.529200   0.525900   380.0000   0.526000     917.000   0.526300
# 2298       18.600000  17.660000     2.7450  17.670000       0.497  17.700000
# 2299        0.020330   0.024200  2556.0000   0.024180     848.000   0.024200
# 2300        0.004770   0.004850  1030.0000   0.004840  331316.000   0.004850
# 2301        1.016000   1.007000     3.5000   1.004000     177.500   1.014000
#
#       ...  openPrice  highPrice   lowPrice        volume   quoteVolume  \
# 0     ...   0.060590   0.061220   0.060500  1.469256e+04  8.937355e+02
# 1     ...   0.002448   0.002454   0.002409  4.038297e+04  9.815622e+01
# 2     ...   0.008079   0.008124   0.008019  2.062900e+04  1.668158e+02
# 3     ...   0.000275   0.000276   0.000271  9.273880e+03  2.540003e+00
# 4     ...   0.001347   0.001353   0.001322  1.776500e+03  2.393554e+00
# ...   ...        ...        ...        ...           ...           ...
# 2297  ...   0.529100   0.591500   0.516100  1.167863e+07  6.452122e+06
# 2298  ...  18.600000  19.830000  17.480000  3.394514e+05  6.295616e+06
# 2299  ...   0.020290   0.025490   0.019690  6.634315e+08  1.553184e+07
# 2300  ...   0.004770   0.005120   0.004700  1.947869e+08  9.572730e+05
# 2301  ...   1.015000   1.015000   1.005000  5.102000e+02  5.157514e+02
#
#            openTime      closeTime    firstId     lastId  count
# 0     1695743430332  1695829830332  423294726  423320991  26266
# 1     1695743430398  1695829830398   93622148   93632403  10256
# 2     1695743430251  1695829830251  227352212  227374579  22368
# 3     1695743415554  1695829815554   45535184   45537245   2062
# 4     1695743420957  1695829820957    5402463    5402509     47
# ...             ...            ...        ...        ...    ...
# 2297  1695743429230  1695829829230     183298     211241  27944
# 2298  1695743429604  1695829829604     550741     593828  43088
# 2299  1695743430176  1695829830176     650722     727739  77018
# 2300  1695743427919  1695829827919      34727      39308   4582
# 2301  1695743347537  1695829747537        128        204     77
#
# [2302 rows x 21 columns]
